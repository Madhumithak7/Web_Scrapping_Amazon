# %%
#import Libraries

from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime

# %%
#connecting to the website
URL='https://www.amazon.de/-/en/CeraVe-Moisturising-Hyaluronic-Essential-Ceramides/dp/B0CBKWWHY9/?_encoding=UTF8&pd_rd_w=1slFB&content-id=amzn1.sym.2eb2166b-927a-4a20-89f8-0eef3f7130c7%3Aamzn1.symc.9b8fba90-e74e-4690-b98f-edc36fe735a6&pf_rd_p=2eb2166b-927a-4a20-89f8-0eef3f7130c7&pf_rd_r=VNDWR45JTPZ0X2DM0EHM&pd_rd_wg=DOnKH&pd_rd_r=e774ad27-3e83-438f-be6f-dbe85fb6eb54&ref_=pd_hp_d_btf_ci_mcx_mr_ca_id_hp_d'

headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser") #need to remember 

soup2 = BeautifulSoup(soup1.prettify(), "html.parser") #we are literally pulling all the Data 

soup3 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup2.find(id='productTitle').get_text()

price = soup2.find(id='corePriceDisplay_desktop_feature_div').get_text()

rating = soup3.find(id='acrPopover').get_text()

print(title)
print(price)
print(rating)
# Out:
#              CeraVe Moisturising Cream for Body and Face, Cream for Dry to Very Dry Skin, with Hyaluronic and 3 Essential Ceramides, 1 x 542 g
#
#
#
#
#
#                  €19.09 with 9 percent savings
#
#
#                  -9%
#
#
#
#
#
#
#                    €
#
#
#                    19
#
#                     .
#
#
#
#                    09
#
#
#
#
#
#
#
#                   &euro;35.22 per kg
#
#
#                   (
#
#
#                     €35.22
#
#
#                     €35.22
#
#
#                   / kg)
#
#
#
#
#
#
#
#                    RRP: €20.90
#
#
#                    RRP:
#
#
#                      €20.90
#
#
#                      €20.90
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      The
#
#                       RRP
#
#                      is the suggested or recommended retail price of a product set by the manufacturer and provided by a manufacturer, supplier or seller. Amazon displays the RRP as a reference price for price comparison purposes.
#
# ...

# %%
price = price.strip()[:6]
rating = rating.strip()[3:]
print(rating)
print(price)
print(title)
# Out:
#
#
#
#                  4.6 out of 5 stars
# €19.09
#
#              CeraVe Moisturising Cream for Body and Face, Cream for Dry to Very Dry Skin, with Hyaluronic and 3 Essential Ceramides, 1 x 542 g

# %%
# Create a Timestamp for your output to track when data was collected

import datetime

today = datetime.date.today()

print(today)
# Out:
# 2024-10-15

# %%
# Create CSV and write headers and data into the file

import csv 

header = ['Title', 'Price','Date','Rating']
data = [title, price,today,rating]


with open('AmazonWebScraperDataset.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv('AmazonWebScraperDataset.csv')

print(df)
# Out:
#                                                Title   Price        Date  \
# 0  \n             CeraVe Moisturising Cream for B...  €19.09  2024-10-15
#
#                                               Rating
# 0  \n               \n\n\n                 4.6 ou...

# %%
#Now we are appending data to the csv

with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:  #a+ we use to appending data
    writer = csv.writer(f)
    writer.writerow(data)

# %%
#Combine all of the above code into one function


def check_price():
    URL='https://www.amazon.de/-/en/CeraVe-Moisturising-Hyaluronic-Essential-Ceramides/dp/B0CBKWWHY9/?_encoding=UTF8&pd_rd_w=1slFB&content-id=amzn1.sym.2eb2166b-927a-4a20-89f8-0eef3f7130c7%3Aamzn1.symc.9b8fba90-e74e-4690-b98f-edc36fe735a6&pf_rd_p=2eb2166b-927a-4a20-89f8-0eef3f7130c7&pf_rd_r=VNDWR45JTPZ0X2DM0EHM&pd_rd_wg=DOnKH&pd_rd_r=e774ad27-3e83-438f-be6f-dbe85fb6eb54&ref_=pd_hp_d_btf_ci_mcx_mr_ca_id_hp_d'

    headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser") #need to remember 

    soup2 = BeautifulSoup(soup1.prettify(), "html.parser") #we are literally pulling all the Data 

    soup3 = BeautifulSoup(soup1.prettify(), "html.parser")

    title = soup2.find(id='productTitle').get_text()

    price = soup2.find(id='corePriceDisplay_desktop_feature_div').get_text()

    rating = soup3.find(id='acrPopover').get_text()

    print(title)
    print(price)
    print(rating)

    import datetime

    today = datetime.date.today()
    
    import csv 

    header = ['Title', 'Price', 'Date','Rating']
    data = [title, price, today,rating]

    with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

    if (price=18):
        send_mail()

# %%
# Runs check_price after a set time and inputs data into your CSV

while(True):
    check_price()
    time.sleep(86400)  #every 24 hours run this process
# Out:
#              CeraVe Moisturising Cream for Body and Face, Cream for Dry to Very Dry Skin, with Hyaluronic and 3 Essential Ceramides, 1 x 542 g
#
#
#
#
#
#                  €19.09 with 9 percent savings
#
#
#                  -9%
#
#
#
#
#
#
#                    €
#
#
#                    19
#
#                     .
#
#
#
#                    09
#
#
#
#
#
#
#
#                   &euro;35.22 per kg
#
#
#                   (
#
#
#                     €35.22
#
#
#                     €35.22
#
#
#                   / kg)
#
#
#
#
#
#
#
#                    RRP: €20.90
#
#
#                    RRP:
#
#
#                      €20.90
#
#
#                      €20.90
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      The
#
#                       RRP
#
#                      is the suggested or recommended retail price of a product set by the manufacturer and provided by a manufacturer, supplier or seller. Amazon displays the RRP as a reference price for price comparison purposes.
#
# ...

# %%
def send_mail():
    server = smtplib.SMTP_SSL('madhumithak722@gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('XXXXXXXX@gmail.com','XXXXXX')
    
    subject = "The moisture you want is 20 euros! Now is your chance to buy!"
    body = "Madhu,  Buy it! Link here: https://www.amazon.de/-/en/CeraVe-Moisturising-Hyaluronic-Essential-Ceramides/dp/B0CBKWWHY9/?_encoding=UTF8&pd_rd_w=1slFB&content-id=amzn1.sym.2eb2166b-927a-4a20-89f8-0eef3f7130c7%3Aamzn1.symc.9b8fba90-e74e-4690-b98f-edc36fe735a6&pf_rd_p=2eb2166b-927a-4a20-89f8-0eef3f7130c7&pf_rd_r=VNDWR45JTPZ0X2DM0EHM&pd_rd_wg=DOnKH&pd_rd_r=e774ad27-3e83-438f-be6f-dbe85fb6eb54&ref_=pd_hp_d_btf_ci_mcx_mr_ca_id_hp_d
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'Madhumithak722@gmail.com',
        msg
     
    )
